# %% [markdown]
# # Data mining using pyiron tables

# %% [markdown]
# In this example, the data mining capabilities of pyiron using the `PyironTables` class is demonstrated by computing and contrasting the ground state properties of fcc-Al using various force fields.

# %%
# %config IPCompleter.greedy=True

# %%
from pyiron_atomistics import Project
import numpy as np

# %%
pr = Project("potential_scan")

# %% [markdown]
# ## Creating a dummy job to get list of potentials
#
# In order to get the list of available LAMMPS potentials, a dummy job with an Al bulk structure is created

# %%
dummy_job = pr.create_job(pr.job_type.Lammps, "dummy_job")
dummy_job.structure = pr.create_ase_bulk("Al")
# Chosing only select potentials to run (you can play with these valuess)
num_potentials = 5
potential_list = dummy_job.list_potentials()[:num_potentials]
# Out:
# /tmp/ipykernel_953/4257926763.py:2: DeprecationWarning: pyiron_atomistics.project.create_ase_bulk is deprecated: Use create.structure.bulk instead.
#   dummy_job.structure = pr.create_ase_bulk("Al")

# %% [markdown]
# ## Creating a Murnaghan job for each potential in their respective subprojects
#
# A separate Murnaghan job (to compute equilibrium lattice constant and the bulk modulus) is created and run for every potential

# %%
for pot in potential_list:
    pot_str = pot.replace("-", "_")
    # open a subproject within a project
    with pr.open(pot_str) as pr_sub:
        # no need for unique job name if in different subprojects 
        job_name = "murn_Al"
        # Use the subproject to create the jobs
        murn = pr_sub.create_job(pr.job_type.Murnaghan, job_name)
        job_ref = pr_sub.create_job(pr.job_type.Lammps, "Al_ref")
        job_ref.structure = pr.create_ase_bulk("Al", cubic=True)
        job_ref.potential = pot
        job_ref.calc_minimize()
        murn.ref_job = job_ref
        # Some potentials may not work with certain LAMMPS compilations.
        # Therefore, we need to have a little exception handling
        try:
            murn.run()
        except RuntimeError:
            pass
# Out:
# /tmp/ipykernel_953/2286477924.py:10: DeprecationWarning: pyiron_atomistics.project.create_ase_bulk is deprecated: Use create.structure.bulk instead.
#   job_ref.structure = pr.create_ase_bulk("Al", cubic=True)
# The job murn_Al was saved and received the ID: 21
# The job murn_Al_0_9 was saved and received the ID: 22
# The job murn_Al_0_92 was saved and received the ID: 23
# The job murn_Al_0_94 was saved and received the ID: 24
# The job murn_Al_0_96 was saved and received the ID: 25
# The job murn_Al_0_98 was saved and received the ID: 26
# The job murn_Al_1_0 was saved and received the ID: 27
# The job murn_Al_1_02 was saved and received the ID: 28
# The job murn_Al_1_04 was saved and received the ID: 29
# The job murn_Al_1_06 was saved and received the ID: 30
# The job murn_Al_1_08 was saved and received the ID: 31
# The job murn_Al_1_1 was saved and received the ID: 32
# /tmp/ipykernel_953/2286477924.py:10: DeprecationWarning: pyiron_atomistics.project.create_ase_bulk is deprecated: Use create.structure.bulk instead.
#   job_ref.structure = pr.create_ase_bulk("Al", cubic=True)
# The job murn_Al was saved and received the ID: 33
# The job murn_Al_0_9 was saved and received the ID: 34
# The job murn_Al_0_92 was saved and received the ID: 35
# The job murn_Al_0_94 was saved and received the ID: 36
# The job murn_Al_0_96 was saved and received the ID: 37
# The job murn_Al_0_98 was saved and received the ID: 38
# The job murn_Al_1_0 was saved and received the ID: 39
# The job murn_Al_1_02 was saved and received the ID: 40
# The job murn_Al_1_04 was saved and received the ID: 41
# The job murn_Al_1_06 was saved and received the ID: 42
# The job murn_Al_1_08 was saved and received the ID: 43
# The job murn_Al_1_1 was saved and received the ID: 44
# 2024-04-03 02:53:45,390 - pyiron_log - WARNING - Minimum could not be found!
# /tmp/ipykernel_953/2286477924.py:10: DeprecationWarning: pyiron_atomistics.project.create_ase_bulk is deprecated: Use create.structure.bulk instead.
#   job_ref.structure = pr.create_ase_bulk("Al", cubic=True)
# The job murn_Al was saved and received the ID: 45
# The job murn_Al_0_9 was saved and received the ID: 46
# The job murn_Al_0_92 was saved and received the ID: 47
# The job murn_Al_0_94 was saved and received the ID: 48
# The job murn_Al_0_96 was saved and received the ID: 49
# The job murn_Al_0_98 was saved and received the ID: 50
# The job murn_Al_1_0 was saved and received the ID: 51
# The job murn_Al_1_02 was saved and received the ID: 52
# The job murn_Al_1_04 was saved and received the ID: 53
# The job murn_Al_1_06 was saved and received the ID: 54
# The job murn_Al_1_08 was saved and received the ID: 55
# The job murn_Al_1_1 was saved and received the ID: 56
# /tmp/ipykernel_953/2286477924.py:10: DeprecationWarning: pyiron_atomistics.project.create_ase_bulk is deprecated: Use create.structure.bulk instead.
#   job_ref.structure = pr.create_ase_bulk("Al", cubic=True)
# The job murn_Al was saved and received the ID: 57
# The job murn_Al_0_9 was saved and received the ID: 58
# The job murn_Al_0_92 was saved and received the ID: 59
# The job murn_Al_0_94 was saved and received the ID: 60
# The job murn_Al_0_96 was saved and received the ID: 61
# The job murn_Al_0_98 was saved and received the ID: 62
# The job murn_Al_1_0 was saved and received the ID: 63
# The job murn_Al_1_02 was saved and received the ID: 64
# The job murn_Al_1_04 was saved and received the ID: 65
# The job murn_Al_1_06 was saved and received the ID: 66
# The job murn_Al_1_08 was saved and received the ID: 67
# The job murn_Al_1_1 was saved and received the ID: 68
# /tmp/ipykernel_953/2286477924.py:10: DeprecationWarning: pyiron_atomistics.project.create_ase_bulk is deprecated: Use create.structure.bulk instead.
#   job_ref.structure = pr.create_ase_bulk("Al", cubic=True)
# The job murn_Al was saved and received the ID: 69
# The job murn_Al_0_9 was saved and received the ID: 70
# The job murn_Al_0_92 was saved and received the ID: 71
# The job murn_Al_0_94 was saved and received the ID: 72
# The job murn_Al_0_96 was saved and received the ID: 73
# The job murn_Al_0_98 was saved and received the ID: 74
# The job murn_Al_1_0 was saved and received the ID: 75
# The job murn_Al_1_02 was saved and received the ID: 76
# The job murn_Al_1_04 was saved and received the ID: 77
# The job murn_Al_1_06 was saved and received the ID: 78
# The job murn_Al_1_08 was saved and received the ID: 79
# The job murn_Al_1_1 was saved and received the ID: 80

# %% [markdown]
# If you inspect the job table, you would find that each Murnaghan job generates various small LAMMPS jobs (see column `hamilton`). Some of these jobs might have failed with status `aborted`.

# %%
pr.job_table()
# Out:
#     id         status chemicalformula           job         subjob  \
# 0   21       finished             Al4       murn_Al       /murn_Al
# 1   22       finished             Al4   murn_Al_0_9   /murn_Al_0_9
# 2   23       finished             Al4  murn_Al_0_92  /murn_Al_0_92
# 3   24       finished             Al4  murn_Al_0_94  /murn_Al_0_94
# 4   25       finished             Al4  murn_Al_0_96  /murn_Al_0_96
# 5   26       finished             Al4  murn_Al_0_98  /murn_Al_0_98
# 6   27       finished             Al4   murn_Al_1_0   /murn_Al_1_0
# 7   28       finished             Al4  murn_Al_1_02  /murn_Al_1_02
# 8   29       finished             Al4  murn_Al_1_04  /murn_Al_1_04
# 9   30       finished             Al4  murn_Al_1_06  /murn_Al_1_06
# 10  31       finished             Al4  murn_Al_1_08  /murn_Al_1_08
# 11  32       finished             Al4   murn_Al_1_1   /murn_Al_1_1
# 12  33  not_converged             Al4       murn_Al       /murn_Al
# 13  34       finished             Al4   murn_Al_0_9   /murn_Al_0_9
# 14  35       finished             Al4  murn_Al_0_92  /murn_Al_0_92
# 15  36       finished             Al4  murn_Al_0_94  /murn_Al_0_94
# 16  37       finished             Al4  murn_Al_0_96  /murn_Al_0_96
# 17  38       finished             Al4  murn_Al_0_98  /murn_Al_0_98
# 18  39       finished             Al4   murn_Al_1_0   /murn_Al_1_0
# 19  40       finished             Al4  murn_Al_1_02  /murn_Al_1_02
# 20  41       finished             Al4  murn_Al_1_04  /murn_Al_1_04
# 21  42       finished             Al4  murn_Al_1_06  /murn_Al_1_06
# 22  43       finished             Al4  murn_Al_1_08  /murn_Al_1_08
# 23  44       finished             Al4   murn_Al_1_1   /murn_Al_1_1
# 24  45       finished             Al4       murn_Al       /murn_Al
# 25  46       finished             Al4   murn_Al_0_9   /murn_Al_0_9
# 26  47       finished             Al4  murn_Al_0_92  /murn_Al_0_92
# 27  48       finished             Al4  murn_Al_0_94  /murn_Al_0_94
# 28  49       finished             Al4  murn_Al_0_96  /murn_Al_0_96
# 29  50       finished             Al4  murn_Al_0_98  /murn_Al_0_98
# 30  51       finished             Al4   murn_Al_1_0   /murn_Al_1_0
# 31  52       finished             Al4  murn_Al_1_02  /murn_Al_1_02
# 32  53       finished             Al4  murn_Al_1_04  /murn_Al_1_04
# 33  54       finished             Al4  murn_Al_1_06  /murn_Al_1_06
# 34  55       finished             Al4  murn_Al_1_08  /murn_Al_1_08
# 35  56       finished             Al4   murn_Al_1_1   /murn_Al_1_1
# 36  57       finished             Al4       murn_Al       /murn_Al
# 37  58       finished             Al4   murn_Al_0_9   /murn_Al_0_9
# 38  59       finished             Al4  murn_Al_0_92  /murn_Al_0_92
# 39  60       finished             Al4  murn_Al_0_94  /murn_Al_0_94
# 40  61       finished             Al4  murn_Al_0_96  /murn_Al_0_96
# 41  62       finished             Al4  murn_Al_0_98  /murn_Al_0_98
# 42  63       finished             Al4   murn_Al_1_0   /murn_Al_1_0
# 43  64       finished             Al4  murn_Al_1_02  /murn_Al_1_02
# 44  65       finished             Al4  murn_Al_1_04  /murn_Al_1_04
# 45  66       finished             Al4  murn_Al_1_06  /murn_Al_1_06
# 46  67       finished             Al4  murn_Al_1_08  /murn_Al_1_08
# 47  68       finished             Al4   murn_Al_1_1   /murn_Al_1_1
# 48  69       finished             Al4       murn_Al       /murn_Al
# 49  70       finished             Al4   murn_Al_0_9   /murn_Al_0_9
# 50  71       finished             Al4  murn_Al_0_92  /murn_Al_0_92
# 51  72       finished             Al4  murn_Al_0_94  /murn_Al_0_94
# 52  73       finished             Al4  murn_Al_0_96  /murn_Al_0_96
# 53  74       finished             Al4  murn_Al_0_98  /murn_Al_0_98
# 54  75       finished             Al4   murn_Al_1_0   /murn_Al_1_0
# 55  76       finished             Al4  murn_Al_1_02  /murn_Al_1_02
# 56  77       finished             Al4  murn_Al_1_04  /murn_Al_1_04
# 57  78       finished             Al4  murn_Al_1_06  /murn_Al_1_06
# 58  79       finished             Al4  murn_Al_1_08  /murn_Al_1_08
# 59  80       finished             Al4   murn_Al_1_1   /murn_Al_1_1
#
#       projectpath  \
# 0   /home/jovyan/
# 1   /home/jovyan/
# 2   /home/jovyan/
# 3   /home/jovyan/
# 4   /home/jovyan/
# 5   /home/jovyan/
# 6   /home/jovyan/
# 7   /home/jovyan/
# 8   /home/jovyan/
# 9   /home/jovyan/
# 10  /home/jovyan/
# 11  /home/jovyan/
# 12  /home/jovyan/
# 13  /home/jovyan/
# 14  /home/jovyan/
# 15  /home/jovyan/
# 16  /home/jovyan/
# 17  /home/jovyan/
# 18  /home/jovyan/
# 19  /home/jovyan/
# 20  /home/jovyan/
# 21  /home/jovyan/
# 22  /home/jovyan/
# 23  /home/jovyan/
# 24  /home/jovyan/
# 25  /home/jovyan/
# 26  /home/jovyan/
# 27  /home/jovyan/
# 28  /home/jovyan/
# 29  /home/jovyan/
# 30  /home/jovyan/
# 31  /home/jovyan/
# 32  /home/jovyan/
# 33  /home/jovyan/
# 34  /home/jovyan/
# 35  /home/jovyan/
# 36  /home/jovyan/
# 37  /home/jovyan/
# 38  /home/jovyan/
# 39  /home/jovyan/
# 40  /home/jovyan/
# 41  /home/jovyan/
# 42  /home/jovyan/
# 43  /home/jovyan/
# 44  /home/jovyan/
# 45  /home/jovyan/
# 46  /home/jovyan/
# 47  /home/jovyan/
# 48  /home/jovyan/
# 49  /home/jovyan/
# 50  /home/jovyan/
# 51  /home/jovyan/
# 52  /home/jovyan/
# 53  /home/jovyan/
# 54  /home/jovyan/
# 55  /home/jovyan/
# 56  /home/jovyan/
# 57  /home/jovyan/
# 58  /home/jovyan/
# 59  /home/jovyan/
#
#                                                                  project  \
# 0                potential_scan/1995__Angelo_J_E__Ni_Al_H__LAMMPS__ipr1/
# 1   potential_scan/1995__Angelo_J_E__Ni_Al_H__LAMMPS__ipr1/murn_Al_hdf5/
# 2   potential_scan/1995__Angelo_J_E__Ni_Al_H__LAMMPS__ipr1/murn_Al_hdf5/
# 3   potential_scan/1995__Angelo_J_E__Ni_Al_H__LAMMPS__ipr1/murn_Al_hdf5/
# 4   potential_scan/1995__Angelo_J_E__Ni_Al_H__LAMMPS__ipr1/murn_Al_hdf5/
# 5   potential_scan/1995__Angelo_J_E__Ni_Al_H__LAMMPS__ipr1/murn_Al_hdf5/
# 6   potential_scan/1995__Angelo_J_E__Ni_Al_H__LAMMPS__ipr1/murn_Al_hdf5/
# 7   potential_scan/1995__Angelo_J_E__Ni_Al_H__LAMMPS__ipr1/murn_Al_hdf5/
# 8   potential_scan/1995__Angelo_J_E__Ni_Al_H__LAMMPS__ipr1/murn_Al_hdf5/
# 9   potential_scan/1995__Angelo_J_E__Ni_Al_H__LAMMPS__ipr1/murn_Al_hdf5/
# 10  potential_scan/1995__Angelo_J_E__Ni_Al_H__LAMMPS__ipr1/murn_Al_hdf5/
# 11  potential_scan/1995__Angelo_J_E__Ni_Al_H__LAMMPS__ipr1/murn_Al_hdf5/
# 12                potential_scan/1996__Farkas_D__Nb_Ti_Al__LAMMPS__ipr1
pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 26        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 27        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 28        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 29        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 30        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 31        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 32        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 33        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 34        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 35        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 36  pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1#11/11
# 37        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 38        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 39        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 40        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 41        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 42        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 43        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 44        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 45        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 46        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 47        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 48  pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1#11/11
# 49        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 50        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 51        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 52        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 53        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 54        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 55        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 56        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 57        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 58        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
# 59        pyiron@jupyter-pyiron-2dworkshop-2dimsi-2dtutorial-2dhrtbbqxy#1
#
#      hamilton hamversion parentid  masterid
# 0   Murnaghan      0.3.0     None       NaN
# 1      Lammps        0.1     None      21.0
# 2      Lammps        0.1     None      21.0
# 3      Lammps        0.1     None      21.0
# 4      Lammps        0.1     None      21.0
# 5      Lammps        0.1     None      21.0
# 6      Lammps        0.1     None      21.0
# 7      Lammps        0.1     None      21.0
# 8      Lammps        0.1     None      21.0
# 9      Lammps        0.1     None      21.0
# 10     Lammps        0.1     None      21.0
# 11     Lammps        0.1     None      21.0
# 12  Murnaghan      0.3.0     None       NaN
# 13     Lammps        0.1     None      33.0
# 14     Lammps        0.1     None      33.0
# 15     Lammps        0.1     None      33.0
# 16     Lammps        0.1     None      33.0
# 17     Lammps        0.1     None      33.0
# 18     Lammps        0.1     None      33.0
# 19     Lammps        0.1     None      33.0
# 20     Lammps        0.1     None      33.0
# 21     Lammps        0.1     None      33.0
# 22     Lammps        0.1     None      33.0
# 23     Lammps        0.1     None      33.0
# 24  Murnaghan      0.3.0     None       NaN
# 25     Lammps        0.1     None      45.0
# 26     Lammps        0.1     None      45.0
# 27     Lammps        0.1     None      45.0
# 28     Lammps        0.1     None      45.0
# 29     Lammps        0.1     None      45.0
# 30     Lammps        0.1     None      45.0
# 31     Lammps        0.1     None      45.0
# 32     Lammps        0.1     None      45.0
# 33     Lammps        0.1     None      45.0
# 34     Lammps        0.1     None      45.0
# 35     Lammps        0.1     None      45.0
# 36  Murnaghan      0.3.0     None       NaN
# 37     Lammps        0.1     None      57.0
# 38     Lammps        0.1     None      57.0
# 39     Lammps        0.1     None      57.0
# 40     Lammps        0.1     None      57.0
# 41     Lammps        0.1     None      57.0
# 42     Lammps        0.1     None      57.0
# 43     Lammps        0.1     None      57.0
# 44     Lammps        0.1     None      57.0
# 45     Lammps        0.1     None      57.0
# 46     Lammps        0.1     None      57.0
# 47     Lammps        0.1     None      57.0
# 48  Murnaghan      0.3.0     None       NaN
# 49     Lammps        0.1     None      69.0
# 50     Lammps        0.1     None      69.0
# 51     Lammps        0.1     None      69.0
# 52     Lammps        0.1     None      69.0
# 53     Lammps        0.1     None      69.0
# 54     Lammps        0.1     None      69.0
# 55     Lammps        0.1     None      69.0
# 56     Lammps        0.1     None      69.0
# 57     Lammps        0.1     None      69.0
# 58     Lammps        0.1     None      69.0
# 59     Lammps        0.1     None      69.0

# %% [markdown]
# ## Analysis using `PyironTables`
#
# The idea now is to go over all finished Murnaghan jobs and extract the equilibrium lattice parameter and bulk modulus, and classify them based of the potential used.

# %% [markdown]
# ### Defining filter functions
#
# Since a project can have thousands if not millions of jobs, it is necessary to "filter" the data and only apply the functions (some of which can be computationally expensive) to only this data. In this example, we need to filter jobs that are finished and are of type `Murnaghan`. This can be done in two ways: using the job table i.e. the entries in the database, or using the job itself i.e. using entries in the stored HDF5 file. Below are examples of filter functions acting on the job and the job table respectively.

# %%
# Filtering using the database entries (which are obtained as a pandas Dataframe)
def db_filter_function(job_table):
    # Returns a pandas Series of boolean values (True for entries that have status finished 
    # and hamilton type Murnaghan.)
    return (job_table.status == "finished") & (job_table.hamilton == "Murnaghan")

# Filtering based on the job
def job_filter_function(job):
    # returns a boolean value if the status of the job 
    #is finished and if "murn" is in it's job name 
    return (job.status == "finished") & ("murn" in job.job_name)

# %% [markdown]
# Obviously, using the database is faster in this case but sometimes it might be necessary to filter based on some data that are stored in the HDF5 file of the job. The database filter is applied first followed by the job based filter.

# %% [markdown]
# ### Defining functions that act on jobs
#
# Now we define a set of functions that will be applied on each job to return a certain value. The filtered jobs will be loaded and these functions will be applied on the loaded jobs. The advantage of such functions is that the jobs do not have to be loaded every time such operations are performed. The filtered jobs are loaded once, and then they are passed to these functions to construct the table.

# %%
# Getting equilibrium lattice parameter from Murnaghan jobs
def get_lattice_parameter(job):
    return job["output/equilibrium_volume"] ** (1/3)

# Getting equilibrium bulk modulus from Murnaghan jobs
def get_bm(job):
    return job["output/equilibrium_bulk_modulus"]

# Getting the potential used in each Murnaghan job
def get_pot(job):
    child = job.project.inspect(job["output/id"][0])
    return child["input/potential/Name"]

# %% [markdown]
# ### Creating a pyiron table
#
# Now that all the functions are defined, the pyiron table called "table" is created in the following way. This works like a job and can be reloaded at any time.

# %%
# %%time
# creating a pyiron table
table = pr.create_table("table")

# assigning a database filter function
table.db_filter_function = db_filter_function

# Alternatively/additionally, a job based filter function can be applied 
# (it does the same thing in this case).

#table.filter_function = job_filter_function

# Adding the functions using the labels you like
table.add["a_eq"] = get_lattice_parameter
table.add["bulk_modulus"] = get_bm
table.add["potential"] = get_pot
# Running the table to generate the data
table.run(run_again=True)
# Out:
# The job table was saved and received the ID: 81
# <timed exec>:17: DeprecationWarning: pyiron_base.jobs.job.generic.run(run_again=True) is deprecated. It is not guaranteed to be in service in vers. 0.4.0
# Loading and filtering jobs:   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/4 [00:00<?, ?it/s]
# CPU times: user 330 ms, sys: 28.5 ms, total: 358 ms
# Wall time: 2.32 s
# /srv/conda/envs/notebook/lib/python3.11/site-packages/pyiron_base/jobs/datamining.py:657: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['potential'], dtype='object')]
#
#   self.pyiron_table._df.to_hdf(

# %% [markdown]
# The output can now be obtained as a pandas DataFrame

# %%
table.get_dataframe()
# Out:
#    job_id      a_eq  bulk_modulus potential
# 0      21  4.049954     81.040445      None
# 1      45  4.032659     83.498560      None
# 2      57  4.033449     90.567635      None
# 3      69  4.032642     83.423053      None

# %% [markdown]
# You can now compare the computed equilibrium lattice constants for each potential to those computed in the NIST database for Al (fcc phase). https://www.ctcms.nist.gov/potentials/system/Al/#Al.
